# %%
import sys
import numpy as np
import tensorflow as tf
import sklearn
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import notebook

# Print Python version
print(f'Python version: {sys.version}')

# Print Jupyter Notebook version
print(f'Jupyter Notebook version: {notebook.__version__}')

# Print library versions
print(f'NumPy version: {np.__version__}')
print(f'TensorFlow version: {tf.__version__}')
print(f'Scikit-learn version: {sklearn.__version__}')
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# Jupyter Notebook version: 7.2.2
# NumPy version: 1.26.4
# TensorFlow version: 2.18.0
# Scikit-learn version: 1.5.1

# %%
import numpy as np
import tensorflow as tf
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import joblib

# Load MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X = mnist.data.values
y = mnist.target.astype(int).values

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the MLP model
def create_mlp(input_dim, hidden_units, output_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(hidden_units, input_dim=input_dim, activation='relu'),
        tf.keras.layers.Dense(output_dim, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Train the MLP model
model = create_mlp(input_dim=X_train.shape[1], hidden_units=256, output_dim=10)
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)

# Evaluate the model on the test data
y_pred = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')  # 'macro' averages for multi-class classification
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# Print evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

print("--------------")


# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# False positives for each class (sum of columns except the diagonal)
false_positives = cm.sum(axis=0) - np.diagonal(cm)

# Print false positives for each class
print("False Alarms for each class:", false_positives)
print("False Alarms for all classes:", false_positives.sum())

#Saving the train and test sets 
joblib.dump((X_train, X_test, y_train, y_test), 'Train_Test_Splits.pkl')

#Saving the model
joblib.dump(model, 'MainModel_1L_MLP.pkl')
# Out:
# C:\Users\dyari\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8857 - loss: 0.3928
# Epoch 2/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9716 - loss: 0.1095
# Epoch 3/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9819 - loss: 0.0689
# Epoch 4/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9883 - loss: 0.0390
# Epoch 5/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9909 - loss: 0.0317
# Epoch 6/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9933 - loss: 0.0234
# Epoch 7/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9932 - loss: 0.0208
# Epoch 8/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9944 - loss: 0.0173
# Epoch 9/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9957 - loss: 0.0138
# Epoch 10/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9950 - loss: 0.0167
# Epoch 11/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9941 - loss: 0.0242
# Epoch 12/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9964 - loss: 0.0139
# Epoch 13/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9972 - loss: 0.0101
# Epoch 14/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9968 - loss: 0.0103
# Epoch 15/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9953 - loss: 0.0184
# Epoch 16/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9962 - loss: 0.0143
# Epoch 17/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9974 - loss: 0.0098
# Epoch 18/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0064
# Epoch 19/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9965 - loss: 0.0124
# Epoch 20/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9964 - loss: 0.0210
# Epoch 21/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9951 - loss: 0.0304
# Epoch 22/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9979 - loss: 0.0115
# Epoch 23/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9983 - loss: 0.0061
# Epoch 24/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9991 - loss: 0.0036
# Epoch 25/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9971 - loss: 0.0115
# Epoch 26/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9967 - loss: 0.0124
# Epoch 27/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9981 - loss: 0.0095
# Epoch 28/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9974 - loss: 0.0218
# Epoch 29/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9981 - loss: 0.0123
# Epoch 30/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9973 - loss: 0.0248
# Epoch 31/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0091
# Epoch 32/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9981 - loss: 0.0096
# Epoch 33/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0027
# Epoch 34/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9975 - loss: 0.0098
# Epoch 35/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9962 - loss: 0.0184
# Epoch 36/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9975 - loss: 0.0182
# Epoch 37/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0051
# Epoch 38/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9968 - loss: 0.0258
# Epoch 39/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9985 - loss: 0.0068
# Epoch 40/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9989 - loss: 0.0064
# Epoch 41/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0032
# Epoch 42/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9985 - loss: 0.0053
# Epoch 43/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9989 - loss: 0.0037
# Epoch 44/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9982 - loss: 0.0089
# Epoch 45/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9970 - loss: 0.0209
# Epoch 46/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9973 - loss: 0.0210
# Epoch 47/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9996 - loss: 0.0021
# Epoch 48/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9986 - loss: 0.0079
# Epoch 49/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9986 - loss: 0.0117
# Epoch 50/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9974 - loss: 0.0265
# Epoch 51/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9969 - loss: 0.0307
# Epoch 52/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9988 - loss: 0.0083
# Epoch 53/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9966 - loss: 0.0539
# Epoch 54/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9981 - loss: 0.0187
# Epoch 55/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9989 - loss: 0.0049
# Epoch 56/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0098
# Epoch 57/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0038
# Epoch 58/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9979 - loss: 0.0104
# Epoch 59/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0035
# Epoch 60/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9970 - loss: 0.0478
# Epoch 61/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0061
# Epoch 62/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0053
# Epoch 63/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0050
# Epoch 64/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9983 - loss: 0.0120
# Epoch 65/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9977 - loss: 0.0545
# Epoch 66/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9985 - loss: 0.0140
# Epoch 67/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9986 - loss: 0.0094
# Epoch 68/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9993 - loss: 0.0061
# Epoch 69/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9967 - loss: 0.0499
# Epoch 70/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9988 - loss: 0.0097
# Epoch 71/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9997 - loss: 0.0023
# Epoch 72/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9997 - loss: 0.0020
# Epoch 73/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0053
# Epoch 74/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9990 - loss: 0.0087
# Epoch 75/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9984 - loss: 0.0155
# Epoch 76/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9983 - loss: 0.0183
# Epoch 77/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9968 - loss: 0.0802
# Epoch 78/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9991 - loss: 0.0086
# Epoch 79/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9991 - loss: 0.0092
# Epoch 80/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0095
# Epoch 81/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9991 - loss: 0.0100
# Epoch 82/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0024
# Epoch 83/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0031
# Epoch 84/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0199
# Epoch 85/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9983 - loss: 0.0160
# Epoch 86/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0043
# Epoch 87/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9997 - loss: 0.0018
# Epoch 88/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9994 - loss: 0.0030
# Epoch 89/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9986 - loss: 0.0068
# Epoch 90/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9994 - loss: 0.0018
# Epoch 91/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9989 - loss: 0.0140
# Epoch 92/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9981 - loss: 0.0205
# Epoch 93/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9980 - loss: 0.0474
# Epoch 94/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9993 - loss: 0.0027
# Epoch 95/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9994 - loss: 0.0033
# Epoch 96/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9998 - loss: 6.9481e-04
# Epoch 97/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9997 - loss: 0.0019
# Epoch 98/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9988 - loss: 0.0106
# Epoch 99/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9993 - loss: 0.0042
# Epoch 100/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9986 - loss: 0.0121
# Accuracy: 0.9739
# Precision: 0.9737
# Recall: 0.9736
# F1 Score: 0.9736
# --------------
# False Alarms for each class: [14 17 46 46 30 47 21 50 38 57]
# False Alarms for all classes: 366
# ['MainModel_1L_MLP.pkl']

# %% [markdown]
# ### Loading and using the same train-test split for other methods

# %% [markdown]
# ### MLP with 2 layers, each having 256 neurons

# %%
import joblib
import numpy as np
import tensorflow as tf
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


X_train, X_test, y_train, y_test = joblib.load(r"Train_Test_Splits.pkl")

# Define the MLP model
def create_mlp(input_dim, hidden_units, output_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(hidden_units, input_dim=input_dim, activation='relu'),
        tf.keras.layers.Dense(hidden_units, input_dim=input_dim, activation='relu'),
        tf.keras.layers.Dense(output_dim, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Train the MLP model
model = create_mlp(input_dim=X_train.shape[1], hidden_units=256, output_dim=10)
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)

# Evaluate the model on the test data
y_pred = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')  # 'macro' averages for multi-class classification
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# Print evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("------------------------")

# Evaluate the model on the test data
y_pred = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# False positives for each class (sum of columns except the diagonal)
false_positives = cm.sum(axis=0) - np.diagonal(cm)

# Print false positives for each class
print("False Positives for each class:", false_positives)
print("False Positives for all classes:", false_positives.sum())

#Saving the model 
joblib.dump(model, 'MLP2L.pkl')
# Out:
# Epoch 1/100
# C:\Users\dyari\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8854 - loss: 0.3810
# Epoch 2/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9739 - loss: 0.0883
# Epoch 3/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9834 - loss: 0.0538
# Epoch 4/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9873 - loss: 0.0393
# Epoch 5/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9892 - loss: 0.0382
# Epoch 6/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9905 - loss: 0.0324
# Epoch 7/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9941 - loss: 0.0178
# Epoch 8/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9920 - loss: 0.0260
# Epoch 9/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9921 - loss: 0.0290
# Epoch 10/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9957 - loss: 0.0153
# Epoch 11/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9943 - loss: 0.0216
# Epoch 12/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9930 - loss: 0.0216
# Epoch 13/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9943 - loss: 0.0236
# Epoch 14/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9963 - loss: 0.0162
# Epoch 15/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9971 - loss: 0.0139
# Epoch 16/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9957 - loss: 0.0152
# Epoch 17/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9960 - loss: 0.0142
# Epoch 18/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9956 - loss: 0.0185
# Epoch 19/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9960 - loss: 0.0169
# Epoch 20/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9968 - loss: 0.0121
# Epoch 21/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0082
# Epoch 22/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9965 - loss: 0.0136
# Epoch 23/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9966 - loss: 0.0136
# Epoch 24/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9958 - loss: 0.0186
# Epoch 25/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9960 - loss: 0.0229
# Epoch 26/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9975 - loss: 0.0088
# Epoch 27/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9965 - loss: 0.0224
# Epoch 28/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9963 - loss: 0.0217
# Epoch 29/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9970 - loss: 0.0223
# Epoch 30/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9981 - loss: 0.0113
# Epoch 31/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9976 - loss: 0.0157
# Epoch 32/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9967 - loss: 0.0205
# Epoch 33/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9966 - loss: 0.0249
# Epoch 34/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0111
# Epoch 35/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9977 - loss: 0.0179
# Epoch 36/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9969 - loss: 0.0323
# Epoch 37/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0111
# Epoch 38/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9983 - loss: 0.0106
# Epoch 39/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9978 - loss: 0.0146
# Epoch 40/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9975 - loss: 0.0147
# Epoch 41/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0157
# Epoch 42/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0167
# Epoch 43/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9972 - loss: 0.0452
# Epoch 44/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9982 - loss: 0.0189
# Epoch 45/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0156
# Epoch 46/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9975 - loss: 0.0213
# Epoch 47/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9984 - loss: 0.0109
# Epoch 48/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9989 - loss: 0.0056
# Epoch 49/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9972 - loss: 0.0196
# Epoch 50/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9982 - loss: 0.0137
# Epoch 51/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9982 - loss: 0.0221
# Epoch 52/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0089
# Epoch 53/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9977 - loss: 0.0253
# Epoch 54/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0228
# Epoch 55/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0095
# Epoch 56/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0090
# Epoch 57/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0175
# Epoch 58/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0187
# Epoch 59/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0109
# Epoch 60/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0129
# Epoch 61/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9974 - loss: 0.0293
# Epoch 62/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0101
# Epoch 63/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0135
# Epoch 64/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9985 - loss: 0.0119
# Epoch 65/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0115
# Epoch 66/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9982 - loss: 0.0305
# Epoch 67/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9974 - loss: 0.0576
# Epoch 68/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9985 - loss: 0.0268
# Epoch 69/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9992 - loss: 0.0133
# Epoch 70/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9988 - loss: 0.0232
# Epoch 71/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9984 - loss: 0.0236
# Epoch 72/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9984 - loss: 0.0286
# Epoch 73/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9989 - loss: 0.0145
# Epoch 74/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9992 - loss: 0.0073
# Epoch 75/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0160
# Epoch 76/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0203
# Epoch 77/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9980 - loss: 0.0244
# Epoch 78/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0197
# Epoch 79/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0491
# Epoch 80/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0246
# Epoch 81/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0137
# Epoch 82/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9980 - loss: 0.0241
# Epoch 83/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9994 - loss: 0.0142
# Epoch 84/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0220
# Epoch 85/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9976 - loss: 0.0759
# Epoch 86/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9989 - loss: 0.0236
# Epoch 87/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9993 - loss: 0.0066
# Epoch 88/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0293
# Epoch 89/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0258
# Epoch 90/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0337
# Epoch 91/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9992 - loss: 0.0184
# Epoch 92/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0111
# Epoch 93/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9993 - loss: 0.0083
# Epoch 94/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9991 - loss: 0.0144
# Epoch 95/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0498
# Epoch 96/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0278
# Epoch 97/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9991 - loss: 0.0279
# Epoch 98/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9997 - loss: 0.0031
# Epoch 99/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9991 - loss: 0.0144
# Epoch 100/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0216
# Accuracy: 0.9745
# Precision: 0.9745
# Recall: 0.9744
# F1 Score: 0.9744
# ------------------------
# False Positives for each class: [17 24 61 28 36 23 34 22 36 76]
# False Positives for all classes: 357
# ['MLP2L.pkl']

# %% [markdown]
# ### CNN with 2 dense layer, one 128 and the other 64 neurons

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix


X_train, X_test, y_train, y_test = joblib.load(r"Train_Test_Splits.pkl")

# Preprocess the data: Normalize and reshape to (28, 28, 1)
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)


# Define the model with a convolutional layer and two hidden layers
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),  # Convolutional layer with 32 filters, kernel size 3x3
    layers.MaxPooling2D((2, 2)),  # MaxPooling layer to reduce spatial dimensions
    layers.Flatten(),  # Flatten the output of the convolutional layer
    layers.Dense(128, activation='relu'),  # First hidden dense layer with 128 units
    layers.Dense(64, activation='relu'),  # Second hidden dense layer with 64 units
    layers.Dense(10, activation='softmax')  # Output layer with 10 units (for 10 classes)
])

# Compile the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test))


# Evaluate the model on the test data
y_pred = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')  # 'macro' averages for multi-class classification
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# Print evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

print("--------------")

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# False positives for each class (sum of columns except the diagonal)
false_positives = cm.sum(axis=0) - np.diagonal(cm)

# Print false positives for each class
print("False Positives for each class:", false_positives)
print("False Positives for all classes:", false_positives.sum())

#Saving the model 
joblib.dump(model, 'CNN_2L.pkl')
# Out:
# Epoch 1/100
# C:\Users\dyari\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.8907 - loss: 0.3808 - val_accuracy: 0.9669 - val_loss: 0.1136
# Epoch 2/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9750 - loss: 0.0818 - val_accuracy: 0.9770 - val_loss: 0.0874
# Epoch 3/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9852 - loss: 0.0510 - val_accuracy: 0.9789 - val_loss: 0.0796
# Epoch 4/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9894 - loss: 0.0371 - val_accuracy: 0.9773 - val_loss: 0.0877
# Epoch 5/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9901 - loss: 0.0351 - val_accuracy: 0.9804 - val_loss: 0.0804
# Epoch 6/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9930 - loss: 0.0291 - val_accuracy: 0.9788 - val_loss: 0.0960
# Epoch 7/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9931 - loss: 0.0229 - val_accuracy: 0.9844 - val_loss: 0.0676
# Epoch 8/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9966 - loss: 0.0121 - val_accuracy: 0.9824 - val_loss: 0.0749
# Epoch 9/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9953 - loss: 0.0152 - val_accuracy: 0.9835 - val_loss: 0.0797
# Epoch 10/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9976 - loss: 0.0085 - val_accuracy: 0.9804 - val_loss: 0.0946
# Epoch 11/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9956 - loss: 0.0154 - val_accuracy: 0.9829 - val_loss: 0.0841
# Epoch 12/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9964 - loss: 0.0129 - val_accuracy: 0.9834 - val_loss: 0.0951
# Epoch 13/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9979 - loss: 0.0084 - val_accuracy: 0.9834 - val_loss: 0.0956
# Epoch 14/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9974 - loss: 0.0099 - val_accuracy: 0.9803 - val_loss: 0.0983
# Epoch 15/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9976 - loss: 0.0083 - val_accuracy: 0.9846 - val_loss: 0.0895
# Epoch 16/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9977 - loss: 0.0090 - val_accuracy: 0.9793 - val_loss: 0.1299
# Epoch 17/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9973 - loss: 0.0110 - val_accuracy: 0.9848 - val_loss: 0.1121
# Epoch 18/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9985 - loss: 0.0071 - val_accuracy: 0.9834 - val_loss: 0.1098
# Epoch 19/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9989 - loss: 0.0052 - val_accuracy: 0.9847 - val_loss: 0.0993
# Epoch 20/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9983 - loss: 0.0079 - val_accuracy: 0.9850 - val_loss: 0.1046
# Epoch 21/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9985 - loss: 0.0074 - val_accuracy: 0.9844 - val_loss: 0.1020
# Epoch 22/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9856 - val_loss: 0.0937
# Epoch 23/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9987 - loss: 0.0064 - val_accuracy: 0.9834 - val_loss: 0.1102
# Epoch 24/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.9831 - val_loss: 0.1182
# Epoch 25/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9823 - val_loss: 0.1287
# Epoch 26/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9980 - loss: 0.0063 - val_accuracy: 0.9844 - val_loss: 0.1120
# Epoch 27/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9981 - loss: 0.0072 - val_accuracy: 0.9856 - val_loss: 0.1223
# Epoch 28/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9993 - loss: 0.0039 - val_accuracy: 0.9852 - val_loss: 0.1295
# Epoch 29/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9987 - loss: 0.0090 - val_accuracy: 0.9851 - val_loss: 0.1292
# Epoch 30/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9829 - val_loss: 0.1351
# Epoch 31/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9842 - val_loss: 0.1360
# Epoch 32/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9835 - val_loss: 0.1441
# Epoch 33/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9844 - val_loss: 0.1395
# Epoch 34/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9991 - loss: 0.0034 - val_accuracy: 0.9856 - val_loss: 0.1500
# Epoch 35/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9987 - loss: 0.0055 - val_accuracy: 0.9824 - val_loss: 0.1622
# Epoch 36/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9981 - loss: 0.0086 - val_accuracy: 0.9836 - val_loss: 0.1438
# Epoch 37/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9852 - val_loss: 0.1458
# Epoch 38/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9839 - val_loss: 0.1529
# Epoch 39/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9987 - loss: 0.0060 - val_accuracy: 0.9829 - val_loss: 0.1633
# Epoch 40/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9989 - loss: 0.0062 - val_accuracy: 0.9852 - val_loss: 0.1666
# Epoch 41/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9984 - loss: 0.0127 - val_accuracy: 0.9852 - val_loss: 0.1685
# Epoch 42/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9993 - loss: 0.0052 - val_accuracy: 0.9819 - val_loss: 0.1912
# Epoch 43/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9985 - loss: 0.0055 - val_accuracy: 0.9859 - val_loss: 0.1677
# Epoch 44/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9998 - loss: 7.3998e-04 - val_accuracy: 0.9853 - val_loss: 0.1664
# Epoch 45/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9998 - loss: 6.8870e-04 - val_accuracy: 0.9831 - val_loss: 0.1945
# Epoch 46/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9987 - loss: 0.0067 - val_accuracy: 0.9846 - val_loss: 0.1911
# Epoch 47/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9990 - loss: 0.0061 - val_accuracy: 0.9852 - val_loss: 0.2008
# Epoch 48/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9994 - loss: 0.0042 - val_accuracy: 0.9837 - val_loss: 0.1921
# Epoch 49/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9828 - val_loss: 0.2298
# Epoch 50/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9987 - loss: 0.0078 - val_accuracy: 0.9831 - val_loss: 0.2078
# Epoch 51/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9846 - val_loss: 0.2156
# Epoch 52/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9992 - loss: 0.0032 - val_accuracy: 0.9851 - val_loss: 0.1927
# Epoch 53/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9846 - val_loss: 0.2163
# Epoch 54/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9846 - val_loss: 0.2032
# Epoch 55/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9990 - loss: 0.0057 - val_accuracy: 0.9833 - val_loss: 0.1896
# Epoch 56/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9989 - loss: 0.0057 - val_accuracy: 0.9836 - val_loss: 0.2188
# Epoch 57/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9993 - loss: 0.0061 - val_accuracy: 0.9840 - val_loss: 0.2014
# Epoch 58/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 0.9826 - val_loss: 0.2136
# Epoch 59/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9842 - val_loss: 0.2158
# Epoch 60/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9851 - val_loss: 0.2079
# Epoch 61/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9991 - loss: 0.0040 - val_accuracy: 0.9836 - val_loss: 0.2246
# Epoch 62/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9852 - val_loss: 0.2372
# Epoch 63/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9843 - val_loss: 0.2317
# Epoch 64/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9833 - val_loss: 0.2716
# Epoch 65/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9990 - loss: 0.0066 - val_accuracy: 0.9841 - val_loss: 0.2722
# Epoch 66/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9995 - loss: 0.0033 - val_accuracy: 0.9847 - val_loss: 0.2435
# Epoch 67/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9837 - val_loss: 0.2560
# Epoch 68/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9988 - loss: 0.0053 - val_accuracy: 0.9817 - val_loss: 0.3205
# Epoch 69/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9813 - val_loss: 0.3233
# Epoch 70/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9994 - loss: 0.0043 - val_accuracy: 0.9843 - val_loss: 0.2717
# Epoch 71/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 0.9846 - val_loss: 0.2839
# Epoch 72/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9834 - val_loss: 0.3211
# Epoch 73/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9988 - loss: 0.0073 - val_accuracy: 0.9854 - val_loss: 0.2610
# Epoch 74/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9851 - val_loss: 0.2595
# Epoch 75/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9999 - loss: 6.3048e-04 - val_accuracy: 0.9850 - val_loss: 0.2455
# Epoch 76/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9997 - loss: 0.0020 - val_accuracy: 0.9848 - val_loss: 0.2647
# Epoch 77/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 0.9844 - val_loss: 0.2854
# Epoch 78/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9991 - loss: 0.0039 - val_accuracy: 0.9842 - val_loss: 0.2744
# Epoch 79/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9991 - loss: 0.0057 - val_accuracy: 0.9847 - val_loss: 0.2771
# Epoch 80/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9827 - val_loss: 0.3204
# Epoch 81/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9994 - loss: 0.0061 - val_accuracy: 0.9846 - val_loss: 0.2698
# Epoch 82/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9847 - val_loss: 0.3033
# Epoch 83/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9998 - loss: 8.6489e-04 - val_accuracy: 0.9848 - val_loss: 0.2725
# Epoch 84/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9997 - loss: 0.0019 - val_accuracy: 0.9832 - val_loss: 0.2807
# Epoch 85/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9846 - val_loss: 0.2764
# Epoch 86/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9843 - val_loss: 0.2876
# Epoch 87/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.9844 - val_loss: 0.2703
# Epoch 88/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9837 - val_loss: 0.2867
# Epoch 89/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9828 - val_loss: 0.2983
# Epoch 90/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9988 - loss: 0.0089 - val_accuracy: 0.9847 - val_loss: 0.2950
# Epoch 91/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9841 - val_loss: 0.2978
# Epoch 92/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9995 - loss: 0.0041 - val_accuracy: 0.9841 - val_loss: 0.2981
# Epoch 93/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9998 - loss: 7.2316e-04 - val_accuracy: 0.9836 - val_loss: 0.2883
# Epoch 94/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9844 - val_loss: 0.3005
# Epoch 95/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9998 - loss: 0.0018 - val_accuracy: 0.9805 - val_loss: 0.3640
# Epoch 96/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9991 - loss: 0.0057 - val_accuracy: 0.9847 - val_loss: 0.2993
# Epoch 97/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9992 - loss: 0.0040 - val_accuracy: 0.9846 - val_loss: 0.3232
# Epoch 98/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9849 - val_loss: 0.3082
# Epoch 99/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 1.0000 - loss: 1.6172e-04 - val_accuracy: 0.9849 - val_loss: 0.3373
# Epoch 100/100
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9996 - loss: 0.0024 - val_accuracy: 0.9835 - val_loss: 0.3340
# Accuracy: 0.9835
# Precision: 0.9836
# Recall: 0.9833
# F1 Score: 0.9834
# --------------
# False Positives for each class: [ 7 21 19 15 22 16 26 39 24 42]
# False Positives for all classes: 231
# ['CNN_2L.pkl']

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import joblib
from sklearn.metrics import confusion_matrix


# Loading the pre-split data for reference 
X_train, X_test, y_train, y_test = joblib.load(r"Train_Test_Splits.pkl")

# Reshape the data
X_train = X_train.reshape(X_train.shape[0], -1)  # Flatten each image to 1D
X_test = X_test.reshape(X_test.shape[0], -1)

# Define the kNN model
model = KNeighborsClassifier(n_neighbors=5)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')  # 'macro' averages for multi-class classification
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# Print evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("--------------------")

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# False positives for each class (sum of columns except the diagonal)
false_positives = cm.sum(axis=0) - np.diagonal(cm)

# Print false positives for each class
print("False Positives for each class:", false_positives)

print("False Positives for all classes:", false_positives.sum())

#Saving the model 
joblib.dump(model, 'kNN_k_5.pkl')
# Out:
# C:\Users\dyari\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\dyari\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\dyari\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dyari\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\dyari\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Accuracy: 0.9461
# Precision: 0.9465
# Recall: 0.9454
# F1 Score: 0.9457
# --------------------
# False Positives for each class: [ 44  75  72  95  73  81  43  88  34 149]
# False Positives for all classes: 754
# ['kNN_k_5.pkl']

# %% [markdown]
# ## Ensember Method: RF

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Loading the pre-split data for reference 
X_train, X_test, y_train, y_test = joblib.load(r"Train_Test_Splits.pkl")


# Flatten the images to 1D vectors
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# Define the Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
model.fit(X_train, y_train)


# Make predictions
y_pred = model.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')  # 'macro' averages for multi-class classification
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

# Print evaluation metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("-----------------------")

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# False positives for each class (sum of columns except the diagonal)
false_positives = cm.sum(axis=0) - np.diagonal(cm)

# Print false positives for each class
print("False Positives for each class:", false_positives)

print("False Positives for all classes:", false_positives.sum())

#Saving the train and test sets 
joblib.dump(model, 'RF.pkl')
# Out:
# Accuracy: 0.9675
# Precision: 0.9673
# Recall: 0.9674
# F1 Score: 0.9673
# -----------------------
# False Positives for each class: [22 27 67 60 50 38 28 50 54 59]
# False Positives for all classes: 455
# ['RF.pkl']
